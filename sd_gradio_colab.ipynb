# %%
cd ..
# Out:
# /content

# %%
# !rm -r ETRI2

# %%
# !git clone https://github.com/5iye/ETRI2.git
# Out:
# Cloning into 'ETRI2'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (13/13), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 13 (delta 4), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (13/13), 8.76 KiB | 8.76 MiB/s, done.
# Resolving deltas: 100% (4/4), done.

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !pip install diffusers==0.23.0
# !pip install gradio
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.11.1
#     Uninstalling diffusers-0.11.1:
#       Successfully uninstalled diffusers-0.11.1
# ...

# %%
# !ls
# Out:
# ETRI2  sample_data

# %%
cd ETRI2
# Out:
# /content/ETRI2

# %%
# !python gradio_app.py
# Out:
# The cache for model files in Diffusers v0.14.0 has moved to a new location. Moving your existing cached models. This is a one-time operation, you can interrupt it or run it later by calling `diffusers.utils.hub_utils.move_cache()`.
# 2023-11-22 13:14:14.499455: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-11-22 13:14:14.499507: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-11-22 13:14:14.499564: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...
